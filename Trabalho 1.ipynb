# %% [markdown]
# #Exercício 1
#
# Faça um programa que dado um numero x, onde x 1000 ≤ x <10000,
# imprima o numero x com seus dígitos na ordem inversa.
# Exemplo: se x = 2736, a resposta será 6372.

# %%
x = int(input())
a = x%1000%100%10
b = x%1000%100 - a
c = x%1000 -(a+b)
d = x - (a+b+c)
# Out:
# 9876

# %%
print("%i%i%i%i" % (a,b/10,c/100,d/1000))
# Out:
# 6789

# %%
x = input()
print(x[3]+x[2]+x[1]+x[0])
# Out:
# 4523
# 3254

# %% [markdown]
# #Exercício 2
# faça um programa que substitui x e y
# Faça um programa que dada a expressão algébrica de uma equação do segundo grau, troque xx por yy e vice versa.
# A equação sempre estará disposta na forma:
# y = ax^2 + bx + c

# %%
x = input().replace("x","y")
print(x.replace("y","x",1)) #substitui apenas o primeiro y
# Out:
# y = -2.43x^2 + 1.40x - 13.44
# x = -2.43y^2 + 1.40y - 13.44

# %% [markdown]
# #Exercício 3
# Dados dois vetores em R 3, dados como entrada na forma:
#
# x1 y1 z1
# x2 y2 z2
#
# Onde x1, y1 e z1 são as coordenadas do primeiro vetor, e x2, y2 e z2 são as coordenadas do segundo vetor.
#
# Calcule:
#
# A soma entre eles;
# O produto escalar;
# O produto vetorial.
#
# xs ys zs
# d
# xc yc zc
#
# Onde:
#
# xs, ys e zs são as coordenadas do vetor resultante da soma;
# d é o valor do produto escalar;
# xc, yc e zc são as coordenadas do vetor resultante do produto vetorial.

# %%
vetor1 = [float(num) for num in input().split()]
vetor2 = [float(num) for num in input().split()]
# Out:
# -15.53 8.84 22.94
# -14.65 -1.01 -22.15

# %%
soma = [vetor1[0]+vetor2[0],vetor1[1]+vetor2[1],vetor1[2]+vetor2[2]]
soma
# Out:
# [-30.18, 7.83, 0.7900000000000027]

# %%
produtoescalar = vetor1[0]*vetor2[0] + vetor1[1]*vetor2[1] + vetor1[2]*vetor2[2]
produtoescalar
# Out:
# -289.5349

# %%
produtovetorial = [vetor1[1]*vetor2[2]-vetor1[2]*vetor2[1], -(vetor1[0]*vetor2[2]-vetor1[2]*vetor2[0]), vetor1[0]*vetor2[1]-vetor1[1]*vetor2[0]]
produtovetorial
# Out:
# [-172.6366, -680.0605, 145.1913]

# %%
print("%.2f %.2f %.2f" % (soma[0],soma[1],soma[2]))
print("%.2f" % produtoescalar)
print("%.2f %.2f %.2f" % (produtovetorial[0], produtovetorial[1], produtovetorial[2]))
# Out:
# -30.18 7.83 0.79
# -289.53
# -172.64 -680.06 145.19

# %%
vetor1 = [float(num) for num in input().split()]
vetor2 = [float(num) for num in input().split()]

soma = [vetor1[0] + vetor2[0], 
        vetor1[1] + vetor2[1], 
        vetor1[2] + vetor2[2]]

produtoescalar = vetor1[0] * vetor2[0] + vetor1[1] * vetor2[1] + vetor1[2] * vetor2[2]

produtovetorial = [vetor1[1] * vetor2[2] - vetor1[2] * vetor2[1], 
                  -(vetor1[0] * vetor2[2] - vetor1[2] * vetor2[0]), 
                  vetor1[0] * vetor2[1] - vetor1[1] * vetor2[0]]

print("%.2f %.2f %.2f" % (soma[0],soma[1],soma[2]))
print("%.2f" % produtoescalar)
print("%.2f %.2f %.2f" % (produtovetorial[0], produtovetorial[1], produtovetorial[2]))
# Out:
# -15.53 8.84 22.94
# -14.65 -1.01 -22.15
# -30.18 7.83 0.79
# -289.53
# -172.64 -680.06 145.19

# %% [markdown]
# #Exercício 4
# Faça um programa que transforme uma temperatura fornecida em Fahrenheit para a correspondente em Celsius.
# A formula de conversão de Fahrenheit para Celsius é a seguinte:
#
# C = 5/9 * (F – 32)
#
# Sample Input:
#
# 83.78
#
# Sample Output:
#
# 28.77

# %%
f = float(input())
c = 5/9 * (f - 32)
print("%.2f" % c)
# Out:
# 83.78
# 28.77

# %% [markdown]
# #Exercício 5
#
#
# Escreva um programa que transforme o valor correspondente a um intervalo temporal, expresso em horas, minutos e segundos, no valor correspondente em segundos.
#
# ```
# Entrada
#
# HH:MM:SS
# ```
# ```
# Saída
#
# total_segundos
# ```

# %%
time = input().split(":")
seconds = int(time[0]) * 3600 + int(time[1]) * 60 + int(time[2])
print(seconds)
# Out:
# 41:13:31
# 148411

# %% [markdown]
# #Exercício 6
#
# Escreva um programa para calcular o valor da função f abaixo
#
# f(a,b) = 3(a+b)^3 + 275b^2 - 127a - 41
#
# dados os valores inteiros a e b.
#
# ###Entrada
# ```
# valor de a
# valor de b
# ```
# ###Saída
# ```
# valor de f(a,b)
# ```

# %%
a = int(input())
b = int(input())

f = 3 * (a + b) ** 3 + 275 * b ** 2 - 127 * a - 41
print(f)
# Out:
# 4
# 7
# 16919

# %% [markdown]
# #Exercício 7
#
# Escreva um programa que leia um inteiro positivo n, n ∈ [1,9] e gera o valor do número n+nn+nnn.
#
# Exemplo: caso n = 1, a saída deve ser 123, pois 1 + 11 + 111 = 123.

# %%
num = int(input())
print(num + num * 11 + num * 111)
# Out:
# 9
# 1107

# %% [markdown]
# #Exercício 8
#
# Escreva um programa que leia um inteiro positivo xx e exiba uma sequência de números x,2x,3x,4x e 5x, separados por três travessões.​
#
# Sample Input 1:
#
# 138
#
# Sample Output 1:
#
# 138---276---414---552---690

# %%
num = int(input())
print(str(num)+"---"+str(num*2)+"---"+str(num*3)+"---"+str(num*4)+"---"+str(num*5))
# Out:
# 138
# 138---276---414---552---690

# %% [markdown]
# #Exercício 9
# Escreva um programa para encontrar os dígitos de um número de quatro dígitos.
#
# Obs: confira nos exemplos abaixo a formatação de entrada e saída do programa.
#
# Sample Input 1:
#
# 8014
#
# Sample Output 1:
# ```
# O primeiro dígito é 8
# O segundo dígito é 0
# O terceiro dígito é 1
# O quarto dígito é 4
# ```

# %%
num = input()
print("O primeiro dígito é {}\nO segundo dígito é {}\nO terceiro dígito é {}\nO quarto dígito é {}" .format(num[0], num[1], num[2], num[3]))
# Out:
# 8014
# O primeiro dígito é 8
# O segundo dígito é 0
# O terceiro dígito é 1
# O quarto dígito é 4

# %% [markdown]
# #Exercício 10
#
# Supondo que k tangerinas serão distribuídas igualmente para n alunos, escreva um programa que calcule quantas tangerinas inteiras cada aluno receberá e quantas tangerinas inteiras permanecerão na cesta!
#
# ###Entrada
# ```
# quantidade de alunos
# quantidade de tangerinas
# ```
# ###Saída
# ```
# quantidade de tangerinas que cada aluno receberá
# quantidade de tangerinas que permanecerão na cesta
# ```

# %%
alunos = int(input())
tangerinas = int(input())

print(tangerinas//alunos)
print(tangerinas%alunos)
# Out:
# 71
# 76
# 1
# 5
